# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_data=pd.read_csv('car data.csv')

# %%
car_data.head()
# Out:
#   Car_Name        company  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0     ritz  maruti suzuki  2014           3.35           5.59       27000
# 1      sx4  maruti suzuki  2013           4.75           9.54       43000
# 2     ciaz  maruti suzuki  2017           7.25           9.85        6900
# 3  wagon r  maruti suzuki  2011           2.85           4.15        5200
# 4    swift  maruti suzuki  2014           4.60           6.87       42450
#
#   Fuel_Type Seller_Type Transmission  Owner
# 0    Petrol      Dealer       Manual      0
# 1    Diesel      Dealer       Manual      0
# 2    Petrol      Dealer       Manual      0
# 3    Petrol      Dealer       Manual      0
# 4    Diesel      Dealer       Manual      0

# %%
car_data.shape
# Out:
# (301, 10)

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   company        301 non-null    object
#  2   Year           301 non-null    int64
#  3   Selling_Price  301 non-null    float64
#  4   Present_Price  301 non-null    float64
#  5   Kms_Driven     301 non-null    int64
#  6   Fuel_Type      301 non-null    object
#  7   Seller_Type    301 non-null    object
#  8   Transmission   301 non-null    object
#  9   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 23.6+ KB

# %%
car_data.isnull().sum()
# Out:
# Car_Name         0
# company          0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %%
car_data.head()
# Out:
#   Car_Name        company  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0     ritz  maruti suzuki  2014           3.35           5.59       27000
# 1      sx4  maruti suzuki  2013           4.75           9.54       43000
# 2     ciaz  maruti suzuki  2017           7.25           9.85        6900
# 3  wagon r  maruti suzuki  2011           2.85           4.15        5200
# 4    swift  maruti suzuki  2014           4.60           6.87       42450
#
#   Fuel_Type Seller_Type Transmission  Owner
# 0    Petrol      Dealer       Manual      0
# 1    Diesel      Dealer       Manual      0
# 2    Petrol      Dealer       Manual      0
# 3    Petrol      Dealer       Manual      0
# 4    Diesel      Dealer       Manual      0

# %% [markdown]
# ## 1. Owner Type

# %%
# Countplot
sns.countplot(x='Owner',data=car_data,palette='Set2')
# Out:
# <AxesSubplot:xlabel='Owner', ylabel='count'>

# %% [markdown]
# ## 2. Transmission Type

# %%
car_data['Transmission'].value_counts()
# Out:
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
sns.countplot(x="Transmission",data=car_data,palette='Set2')
# Out:
# <AxesSubplot:xlabel='Transmission', ylabel='count'>

# %% [markdown]
# ## 3. Fuel Type

# %%
sns.countplot(x="Fuel_Type",data=car_data,palette='Set2')
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='count'>

# %% [markdown]
# ## 4. Year of Manufacture

# %%
car_data['Year'].mean()
# Out:
# 2013.6279069767443

# %%
car_data['Year'].min()
# Out:
# 2003

# %%
car_data['Year'].max()
# Out:
# 2018

# %% [markdown]
# ## 5. Company

# %%
sns.countplot(x="company", data=car_data,palette="Set2")
# Out:
# <AxesSubplot:xlabel='company', ylabel='count'>

# %%
sns.countplot(x="Car_Name",data=car_data,palette="Set2")
# Out:
# <AxesSubplot:xlabel='Car_Name', ylabel='count'>

# %% [markdown]
# # DATA ANALYSIS

# %% [markdown]
# ## OWNER TYPE

# %% [markdown]
# ###### SELLING PRICE BASED ON OWNERSHIP

# %%
sns.barplot(x="Owner",y="Selling_Price",data=car_data,palette="Set2")
# Out:
# <AxesSubplot:xlabel='Owner', ylabel='Selling_Price'>

# %% [markdown]
# ###### Selling price of vehicle belonging to 0 owner is highest.

# %% [markdown]
# ## TRANSMISSION TYPE

# %% [markdown]
# ###### SELLING PRICE BASED ON  TRANSMISSION

# %%
sns.barplot(x="Transmission",y="Selling_Price",data=car_data,palette="Set2")
# Out:
# <AxesSubplot:xlabel='Transmission', ylabel='Selling_Price'>

# %% [markdown]
# ###### Cost price based on transmission

# %%
sns.barplot(x="Transmission",y="Present_Price",data=car_data,palette="Set2")
# Out:
# <AxesSubplot:xlabel='Transmission', ylabel='Present_Price'>

# %% [markdown]
# ###### Automatic transmission cars have high present price as well as selling price.

# %% [markdown]
# ## FUEL TYPE

# %%
sns.barplot(x="Fuel_Type",y="Present_Price",data=car_data,palette="Set2")
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='Present_Price'>

# %%
sns.barplot(x="Fuel_Type",y="Selling_Price",data=car_data,palette="Set2")
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='Selling_Price'>

# %% [markdown]
# ###### Selling and cost price of diesel cars is highest whereas cng have high present price but low selling price than petrol

# %% [markdown]
# ## DEALER

# %%
sns.barplot(x="Seller_Type",y="Selling_Price",data=car_data,palette="Set2")
# Out:
# <AxesSubplot:xlabel='Seller_Type', ylabel='Selling_Price'>

# %%
plt.figure(figsize=(10,10))
sns.lmplot(x='Kms_Driven',y='Selling_Price',data=car_data)

# %%
plt.figure(figsize=(10,10))
sns.lmplot(x='Present_Price',y='Selling_Price',data=car_data)

# %%
#creating a new column 'Vehicle_Age' and storing the age of the vehicles to establish a direct relationship between the age and selling price
car_data['Vehicle_Age']=2020- car_data['Year']

#check out the newly added column
car_data.tail(10)
# Out:
#     Car_Name company  Year  Selling_Price  Present_Price  Kms_Driven  \
# 291     brio   honda  2015           5.40           6.10       31427
# 292     jazz   honda  2016           6.40           8.40       12000
# 293     city   honda  2010           3.25           9.90       38000
# 294    amaze   honda  2014           3.75           6.80       33019
# 295     city   honda  2015           8.55          13.09       60076
# 296     city   honda  2016           9.50          11.60       33988
# 297     brio   honda  2015           4.00           5.90       60000
# 298     city   honda  2009           3.35          11.00       87934
# 299     city   honda  2017          11.50          12.50        9000
# 300     brio   honda  2016           5.30           5.90        5464
#
#     Fuel_Type Seller_Type Transmission  Owner  Vehicle_Age
# 291    Petrol      Dealer       Manual      0            5
# 292    Petrol      Dealer       Manual      0            4
# ...

# %%
plt.figure(figsize=(10,10))
sns.regplot(x='Vehicle_Age',y='Selling_Price',data=car_data)
# Out:
# <AxesSubplot:xlabel='Vehicle_Age', ylabel='Selling_Price'>

# %% [markdown]
# # CATEGORICAL VALUES TO MUMERICAL VALUES

# %%
car_data.tail()
# Out:
#     Car_Name company  Year  Selling_Price  Present_Price  Kms_Driven  \
# 296     city   honda  2016           9.50           11.6       33988
# 297     brio   honda  2015           4.00            5.9       60000
# 298     city   honda  2009           3.35           11.0       87934
# 299     city   honda  2017          11.50           12.5        9000
# 300     brio   honda  2016           5.30            5.9        5464
#
#     Fuel_Type Seller_Type Transmission  Owner  Vehicle_Age
# 296    Diesel      Dealer       Manual      0            4
# 297    Petrol      Dealer       Manual      0            5
# 298    Petrol      Dealer       Manual      0           11
# 299    Diesel      Dealer       Manual      0            3
# 300    Petrol      Dealer       Manual      0            4

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
car_data['Fuel_Type']=lb.fit_transform(car_data['Fuel_Type'])
car_data['Seller_Type']=lb.fit_transform(car_data['Seller_Type'])
car_data['Transmission']=lb.fit_transform(car_data['Transmission'])

# %%
car_data.tail()
# Out:
#     Car_Name company  Year  Selling_Price  Present_Price  Kms_Driven  \
# 296     city   honda  2016           9.50           11.6       33988
# 297     brio   honda  2015           4.00            5.9       60000
# 298     city   honda  2009           3.35           11.0       87934
# 299     city   honda  2017          11.50           12.5        9000
# 300     brio   honda  2016           5.30            5.9        5464
#
#      Fuel_Type  Seller_Type  Transmission  Owner  Vehicle_Age
# 296          1            0             1      0            4
# 297          2            0             1      0            5
# 298          2            0             1      0           11
# 299          1            0             1      0            3
# 300          2            0             1      0            4

# %% [markdown]
# ###### FUEL TYPE-> PETROL:2, DIESEL:1, CNG:0

# %% [markdown]
# ###### SELLER TYPE-> DEALER:0, INDIVIDUAL:1

# %% [markdown]
# ###### TRANSMISSION-> AUTOMATIC:0, MANUAL:1

# %%
sns.pairplot(car_data)

# %%
correlations = car_data.corr()

indx=correlations.index
plt.figure(figsize=(26,22))
sns.heatmap(car_data[indx].corr(),annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
car_data.drop(['Year'],axis=1,inplace=True)

# %%
car_data.head()
# Out:
#   Car_Name        company  Selling_Price  Present_Price  Kms_Driven  \
# 0     ritz  maruti suzuki           3.35           5.59       27000
# 1      sx4  maruti suzuki           4.75           9.54       43000
# 2     ciaz  maruti suzuki           7.25           9.85        6900
# 3  wagon r  maruti suzuki           2.85           4.15        5200
# 4    swift  maruti suzuki           4.60           6.87       42450
#
#    Fuel_Type  Seller_Type  Transmission  Owner  Vehicle_Age
# 0          2            0             1      0            6
# 1          1            0             1      0            7
# 2          2            0             1      0            3
# 3          2            0             1      0            9
# 4          1            0             1      0            6

# %% [markdown]
# # MODEL BUILDING

# %%
x=car_data.drop(columns=['Selling_Price','Car_Name','company'],axis=1)
y=car_data['Selling_Price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((240, 7), (61, 7), (240,), (61,))

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred_model=regressor.predict(x)

# %%
y_pred_model
# Out:
# array([ 3.87640397e+00,  6.62510656e+00,  7.11626916e+00,  2.16129657e+00,
#         5.84177474e+00,  9.03506476e+00,  5.46099107e+00,  7.07923989e+00,
#         7.69192117e+00,  7.16052407e+00,  4.35922406e+00,  7.75663721e+00,
#         7.72729986e+00,  5.23221743e+00,  2.25773938e+00,  8.39443191e+00,
#         7.99891120e+00,  8.39443191e+00,  6.98915300e+00,  3.23446862e+00,
#         3.96562831e+00,  5.29856714e+00,  5.02766258e+00,  2.80993341e+00,
#         2.75574041e+00,  2.44158878e+00,  3.41797850e+00,  4.45479535e+00,
#         1.41738196e+00,  7.79488183e+00,  4.57965511e+00,  2.17899577e+00,
#         6.14027724e+00,  7.19916022e+00,  6.35624511e+00,  6.46281727e+00,
#         4.85964494e+00, -3.78432163e+00,  3.97599881e+00,  2.75798910e-01,
#         7.14734743e+00,  3.03275709e+00,  1.95086260e+00,  6.35127331e+00,
#         1.62854324e+00,  8.25992494e+00,  2.92103307e+00, -2.39611155e-01,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y,y_pred_model)*100
# Out:
# 87.85205982910809

# %% [markdown]
# BOOST APPLIED

# %%
import xgboost
from sklearn.model_selection import RandomizedSearchCV
regressor=xgboost.XGBRegressor()

# %%
#Hyperparamter_Tuning
n_estimators = [100, 500, 900, 1100, 1500]
max_depth = [2, 3, 5, 10, 15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]
base_score=[0.25,0.5,0.75,1]

# Define the grid of hyperparameters to search
parameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }

# %%
# Set up the random search with 5-fold cross validation
random_cv = RandomizedSearchCV(estimator=regressor,
            param_distributions=parameter_grid,
            cv=5, n_iter=50,
            scoring = 'neg_mean_absolute_error',n_jobs = 3,
            verbose = 5, 
            return_train_score = True,
            random_state=42)

#train on the RandomSearchCv object to get best estimators
random_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           enable_categorical=False, gamma=None,
#                                           gpu_id=None, importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=None,
#                                           max_delta_step=None, max_depth=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=...
#                                           validate_parameters=None,
# ...

# %%
#getting the best estimators
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.15, max_delta_step=0,
#              max_depth=15, min_child_weight=3, missing=nan,
#              monotone_constraints='()', n_estimators=1500, n_jobs=12,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
#getting the best params
random_cv.best_params_
# Out:
# {'n_estimators': 1500,
#  'min_child_weight': 3,
#  'max_depth': 15,
#  'learning_rate': 0.15,
#  'booster': 'gbtree',
#  'base_score': 0.5}

# %%
# reinitializing the regressor object with the best probable estimators
regressor=xgboost.XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
             importance_type=None, interaction_constraints='',
             learning_rate=0.15, max_delta_step=0, max_depth=15,
             min_child_weight=3, missing=np.nan, monotone_constraints='()',
             n_estimators=1500, n_jobs=12, num_parallel_tree=1, random_state=0,
             reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
             tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# fitting the xgbRegressor on our training data
regressor.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.15, max_delta_step=0,
#              max_depth=15, min_child_weight=3, missing=nan,
#              monotone_constraints='()', n_estimators=1500, n_jobs=12,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
# fetching the predictions on our test data
predictions2=regressor.predict(X_test)

# %%
predictions2
# Out:
# array([12.332029  ,  2.9210525 ,  2.827521  ,  5.3555026 ,  0.85158986,
#         0.32934844,  6.842262  ,  3.2070174 ,  5.136216  ,  6.900824  ,
#         0.18302095,  1.1034378 ,  0.43339854,  6.3959274 ,  5.2309556 ,
#         4.6796517 ,  4.2575326 ,  5.1309204 ,  7.906078  ,  1.4285191 ,
#         0.4604575 , 22.997784  ,  4.929153  , 27.912151  ,  4.099274  ,
#         4.4579134 ,  9.540018  ,  0.2487275 ,  1.3525958 ,  2.1550674 ,
#        14.882784  ,  0.33263013,  1.0896633 ,  4.316556  ,  3.0260003 ,
#        10.552304  ,  4.4189568 ,  6.7150803 ,  1.6639613 ,  6.891518  ,
#         0.43177298,  5.7473116 ,  0.41384724,  4.6703715 ,  0.6031128 ,
#         1.4162931 ,  5.6469474 ,  3.333494  ,  5.128755  , 22.937653  ,
#         1.5625806 ,  8.655707  ,  6.9652143 ,  7.6575303 ,  4.9900665 ,
#         4.70958   ,  0.1161596 ,  2.961658  ,  5.4903975 ,  2.9340954 ,
#         5.215833  ], dtype=float32)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,predictions2)*100
# Out:
# 92.70735207325606

# %%
car_data.shape
# Out:
# (301, 10)

# %%
car_data.ndim
# Out:
# 2

# %%
x_car_test=np.array([16.38,72000,1,1,1,0,10])

# %%
x_car_test.shape
# Out:
# (7,)

# %%
X_test.ndim
# Out:
# 2

# %%
X_test
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 211          14.79       43535          1            0             1      0
# 298          11.00       87934          2            0             1      0
# 28            3.95       44542          2            0             1      0
# 286           7.90       28569          2            0             1      0
# 132           0.95        3500          2            1             1      0
# ..             ...         ...        ...          ...           ...    ...
# 189           0.57       55000          2            1             1      0
# 24            4.41       56879          2            0             1      0
# 300           5.90        5464          2            0             1      0
# 236           4.43       11849          2            0             1      0
# 206           7.13       12479          2            0             1      0
#
#      Vehicle_Age
# 211            5
# 298           11
# ...

# %%
x_car_test=x_car_test.reshape((1,7))

# %%
x_car_test.shape
# Out:
# (1, 7)

# %%
# fetching the predictions on our test data
predictions3=regressor.predict(x_car_test)

# %%
predictions3
# Out:
# array([4.960591], dtype=float32)

# %%
current_price=float(input("Enter value if new car"))
kms=int(input("Enter kms"))
fuel=int(input("Enter fuel type if cng enter:0,if diesel then 1:,else 2: "))
seller=int(input("1 for indivual and 0 for dealer"))
trans=int(input("0 for automatic and 1 for manual:"))
owner=int(input("No of previous owners:"))
age=int(input("Age of vehicle"))
x_car_test=np.array([current_price,kms,fuel,seller,trans,owner,age])
x_car_test=x_car_test.reshape((1,7))
predictions=regressor.predict(x_car_test)
predictions
# Out:
# Enter value if new car10.29
# Enter kms9
# Enter fuel type if cng enter:0,if diesel then 1:,else 2: 1
# 1 for indivual and 0 for dealer1
# 0 for automatic and 1 for manual:1
# No of previous owners:1
# Age of vehicle9
# array([4.7380967], dtype=float32)

# %%
current_price=float(input("Enter value if new car"))
kms=int(input("Enter kms"))
fuel=int(input("Enter fuel type if cng enter:0,if diesel then 1:,else 2: "))
seller=int(input("1 for indivual and 0 for dealer"))
trans=int(input("0 for automatic and 1 for manual:"))
owner=int(input("No of previous owners:"))
age=int(input("Age of vehicle"))
x_car_test=np.array([current_price,kms,fuel,seller,trans,owner,age])
x_car_test=x_car_test.reshape((1,7))
predictions=regressor.predict(x_car_test)
predictions
# Out:
# Enter value if new car11.21
# Enter kms28000
# Enter fuel type if cng enter:0,if diesel then 1:,else 2: 1
# 1 for indivual and 0 for dealer0
# 0 for automatic and 1 for manual:1
# No of previous owners:0
# Age of vehicle4
# array([7.9916654], dtype=float32)

# %%
current_price=float(input("Enter value if new car"))
kms=int(input("Enter kms"))
fuel=int(input("Enter fuel type if cng enter:0,if diesel then 1:,else 2: "))
seller=int(input("1 for indivual and 0 for dealer"))
trans=int(input("0 for automatic and 1 for manual:"))
owner=int(input("No of previous owners:"))
age=int(input("Age of vehicle"))
x_car_test=np.array([current_price,kms,fuel,seller,trans,owner,age])
x_car_test=x_car_test.reshape((1,7))
predictions=regressor.predict(x_car_test)
predictions
# Out:
# Enter value if new car77.85
# Enter kms27000
# Enter fuel type if cng enter:0,if diesel then 1:,else 2: 1
# 1 for indivual and 0 for dealer0
# 0 for automatic and 1 for manual:0
# No of previous owners:0
# Age of vehicle3
# array([30.022095], dtype=float32)
